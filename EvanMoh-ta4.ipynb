# %% [markdown]
# Assignment 4 -Data Exploration (Evan Moh - AIPI510 Fall 2024)
#
# First, import all the libraries necessary for the analysis and importing datasets.

# %%
import pandas as pd

heart_rate = pd.read_csv('hrv-covid19/data/heart_rate.csv')
blood_pressure = pd.read_csv('hrv-covid19/data/blood_pressure.csv')
hrv_measurements= pd.read_csv('hrv-covid19/data/hrv_measurements.csv')
participants = pd.read_csv('hrv-covid19/data/participants.csv')
scales_description= pd.read_csv('hrv-covid19/data/scales_description.csv')
surveys= pd.read_csv('hrv-covid19/data/surveys.csv')
wearables= pd.read_csv('hrv-covid19/data/wearables.csv')
weather= pd.read_csv('hrv-covid19/data/weather.csv')
# Out:
#        user_code         day  avg_temperature_C  atmospheric_pressure  \
# 0     013f6d3e5b  2020-05-22            18.0667                1017.6
# 1     01bad5a519  2020-01-11            -1.2111                1016.4
# 2     01bad5a519  2020-01-30             0.5056                1004.7
# 3     01bad5a519  2020-04-02            -0.2444                 994.4
# 4     01bad5a519  2020-04-12             5.1778                1016.1
# ...          ...         ...                ...                   ...
# 1712  fde84801d8  2020-06-14            16.2944                1017.2
# 1713  fde84801d8  2020-06-17            19.5667                1018.6
# 1714  fde84801d8  2020-06-18            28.5889                1016.2
# 1715  fde84801d8  2020-06-19            21.5222                1016.4
# 1716  fe5ca7e4ea  2020-05-02            24.5944                1015.2
#
#       precip_intensity  humidity  clouds
# 0               0.0002      70.0    67.0
# 1               0.0002      92.0     6.0
# 2               0.0009      85.0   100.0
# 3               0.0025      91.0    87.0
# 4               0.0000      61.0    91.0
# ...                ...       ...     ...
# 1712            0.0061      81.0   100.0
# 1713            0.0002      51.0    11.0
# 1714            0.0000      52.0    30.0
# 1715            0.0004      85.0    44.0
# 1716            0.0002      56.0    47.0
#
# [1717 rows x 7 columns]
