# %%
import pandas as pd
import sqlite3 as sq

# %%
conn = sq.connect('ta2.db')

# %%
df = pd.read_csv('data/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.to_sql('tips', conn, if_exists='replace', index=False)
# Out:
# 244

# %%
cur = conn.cursor()

# %%
for row in cur.execute('SELECT * FROM tips'):
    print(row)
# Out:
# (16.99, 1.01, 'Female', 'No', 'Sun', 'Dinner', 2)
# (10.34, 1.66, 'Male', 'No', 'Sun', 'Dinner', 3)
# (21.01, 3.5, 'Male', 'No', 'Sun', 'Dinner', 3)
# (23.68, 3.31, 'Male', 'No', 'Sun', 'Dinner', 2)
# (24.59, 3.61, 'Female', 'No', 'Sun', 'Dinner', 4)
# (25.29, 4.71, 'Male', 'No', 'Sun', 'Dinner', 4)
# (8.77, 2.0, 'Male', 'No', 'Sun', 'Dinner', 2)
# (26.88, 3.12, 'Male', 'No', 'Sun', 'Dinner', 4)
# (15.04, 1.96, 'Male', 'No', 'Sun', 'Dinner', 2)
# (14.78, 3.23, 'Male', 'No', 'Sun', 'Dinner', 2)
# (10.27, 1.71, 'Male', 'No', 'Sun', 'Dinner', 2)
# (35.26, 5.0, 'Female', 'No', 'Sun', 'Dinner', 4)
# (15.42, 1.57, 'Male', 'No', 'Sun', 'Dinner', 2)
# (18.43, 3.0, 'Male', 'No', 'Sun', 'Dinner', 4)
# (14.83, 3.02, 'Female', 'No', 'Sun', 'Dinner', 2)
# (21.58, 3.92, 'Male', 'No', 'Sun', 'Dinner', 2)
# (10.33, 1.67, 'Female', 'No', 'Sun', 'Dinner', 3)
# (16.29, 3.71, 'Male', 'No', 'Sun', 'Dinner', 3)
# (16.97, 3.5, 'Female', 'No', 'Sun', 'Dinner', 3)
# ...

# %%
#Find the maximum and minimum total bill amounts
cur.execute('SELECT MAX(total_bill) FROM tips')
print("Max Value: ")
print(cur.fetchone()[0])

cur.execute('SELECT MIN(total_bill) FROM tips')
print("Min Value: ")
print(cur.fetchone()[0])
# Out:
# Max Value:
# 50.81
# Min Value:
# 3.07

# %%
#Retrieve the total bill and tip for parties of size 4 or more, where the tip percentage is greater than 15%
query = ''' SELECT total_bill, tip
FROM tips
WHERE size >= 4 AND (tip/total_bill)*100 > 15
'''

for row in cur.execute(query):
    print(row)
# Out:
# (25.29, 4.71)
# (18.43, 3.0)
# (39.42, 7.58)
# (30.4, 5.6)
# (32.4, 6.0)
# (25.56, 4.34)
# (18.29, 3.76)
# (29.93, 5.07)
# (34.3, 6.7)
# (27.05, 5.0)
# (29.85, 5.14)
# (21.5, 3.5)
# (23.17, 6.5)
# (20.69, 5.0)
# (20.53, 4.0)
# (25.89, 5.16)
# (48.33, 9.0)

# %%
#Find the average tip percentage for each combination of day, time, and smoker status

query = ''' SELECT day, time, smoker, ROUND(AVG((tip/total_bill)*100),2) AS tip_percent_avg
FROM tips
GROUP BY day, time, smoker
'''

for row in cur.execute(query):
    print(row)
# Out:
# ('Fri', 'Dinner', 'No', 13.96)
# ('Fri', 'Dinner', 'Yes', 16.53)
# ('Fri', 'Lunch', 'No', 18.77)
# ('Fri', 'Lunch', 'Yes', 18.89)
# ('Sat', 'Dinner', 'No', 15.8)
# ('Sat', 'Dinner', 'Yes', 14.79)
# ('Sun', 'Dinner', 'No', 16.01)
# ('Sun', 'Dinner', 'Yes', 18.73)
# ('Thur', 'Dinner', 'No', 15.97)
# ('Thur', 'Lunch', 'No', 16.03)
# ('Thur', 'Lunch', 'Yes', 16.39)

# %%
#Find the maximum and minimum tip percentage for each day and time combination, along with the corresponding total bill and tip amount

query = ''' SELECT total_bill, tip, day, time, smoker, ROUND(MAX((tip/total_bill)*100),2) AS tip_percent_max
FROM tips
GROUP BY day, time, smoker
'''

print("Maximums:")
for row in cur.execute(query):
    print(row)

query = ''' SELECT total_bill, tip, day, time, smoker, ROUND(MIN((tip/total_bill)*100),2) AS tip_percent_min
FROM tips
GROUP BY day, time, smoker
'''

print("Minimums:")
for row in cur.execute(query):
    print(row)
# Out:
# Maximums:
# (22.49, 3.5, 'Fri', 'Dinner', 'No', 15.56)
# (16.32, 4.3, 'Fri', 'Dinner', 'Yes', 26.35)
# (15.98, 3.0, 'Fri', 'Lunch', 'No', 18.77)
# (13.42, 3.48, 'Fri', 'Lunch', 'Yes', 25.93)
# (11.61, 3.39, 'Sat', 'Dinner', 'No', 29.2)
# (3.07, 1.0, 'Sat', 'Dinner', 'Yes', 32.57)
# (10.29, 2.6, 'Sun', 'Dinner', 'No', 25.27)
# (7.25, 5.15, 'Sun', 'Dinner', 'Yes', 71.03)
# (18.78, 3.0, 'Thur', 'Dinner', 'No', 15.97)
# (7.51, 2.0, 'Thur', 'Lunch', 'No', 26.63)
# (16.58, 4.0, 'Thur', 'Lunch', 'Yes', 24.13)
# Minimums:
# (12.46, 1.5, 'Fri', 'Dinner', 'No', 12.04)
# (28.97, 3.0, 'Fri', 'Dinner', 'Yes', 10.36)
# (15.98, 3.0, 'Fri', 'Lunch', 'No', 18.77)
# (13.42, 1.58, 'Fri', 'Lunch', 'Yes', 11.77)
# (26.41, 1.5, 'Sat', 'Dinner', 'No', 5.68)
# (32.83, 1.17, 'Sat', 'Dinner', 'Yes', 3.56)
# (16.99, 1.01, 'Sun', 'Dinner', 'No', 5.94)
# (30.46, 2.0, 'Sun', 'Dinner', 'Yes', 6.57)
# (18.78, 3.0, 'Thur', 'Dinner', 'No', 15.97)
# (18.64, 1.36, 'Thur', 'Lunch', 'No', 7.3)
# ...

# %%
#Find the average tip percentage for each combination of day, time, and smoker status, but only include combinations with more than 5 records
query = ''' SELECT day, time, smoker, ROUND(AVG((tip/total_bill)*100),2) AS tip_percent_avg
FROM tips
GROUP BY day, time, smoker
HAVING COUNT(*) > 5
'''

for row in cur.execute(query):
    print(row)
# Out:
# ('Fri', 'Dinner', 'Yes', 16.53)
# ('Fri', 'Lunch', 'Yes', 18.89)
# ('Sat', 'Dinner', 'No', 15.8)
# ('Sat', 'Dinner', 'Yes', 14.79)
# ('Sun', 'Dinner', 'No', 16.01)
# ('Sun', 'Dinner', 'Yes', 18.73)
# ('Thur', 'Lunch', 'No', 16.03)
# ('Thur', 'Lunch', 'Yes', 16.39)

# %%
conn.close()
