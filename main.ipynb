# %%
import json
import pandas as pd

file = open('data.json','r')
data = file.read()
data = json.loads(data)

# %%
dataframe = pd.DataFrame(data['docs'])
dataframe
# Out:
#              _version_                                    alternate_names  \
# 0  1801141574630899712  [Joanne Rowling, Joanne K. Rowling, Jo Murray,...
# 1  1795985891139780617                                                NaN
# 2  1802121658726612993                                                NaN
# 3  1802200739548758016                                                NaN
#
#      birth_date          key                 name  \
# 0  31 July 1965     OL23919A        J. K. Rowling
# 1           NaN  OL13412347A        J. K. Rowling
# 2           NaN  OL13696009A        J. K. ROWLING
# 3           NaN  OL13730612A  J. K. Rowling Miles
#
#                                         top_subjects  \
# 0  [Children's fiction, Fantasy fiction, Wizards,...
# 1  [Wizards, Motion pictures, miscellanea, Magic,...
# 2                                                NaN
# 3                                                NaN
#
#                                    top_work    type  work_count
# ...
